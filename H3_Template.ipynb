# %%
! pip install keplergl
# Out:
# Requirement already satisfied: keplergl in /opt/conda/lib/python3.7/site-packages (0.3.2)
# Requirement already satisfied: ipywidgets<8,>=7.0.0 in /opt/conda/lib/python3.7/site-packages (from keplergl) (7.5.1)
# Requirement already satisfied: Shapely>=1.6.4.post2 in /opt/conda/lib/python3.7/site-packages (from keplergl) (1.8.0)
# Requirement already satisfied: traittypes>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from keplergl) (0.2.1)
# Requirement already satisfied: pandas>=0.23.0 in /opt/conda/lib/python3.7/site-packages (from keplergl) (1.2.3)
# Requirement already satisfied: geopandas>=0.5.0 in /opt/conda/lib/python3.7/site-packages (from keplergl) (0.10.2)
# Requirement already satisfied: fiona>=1.8 in /opt/conda/lib/python3.7/site-packages (from geopandas>=0.5.0->keplergl) (1.8.21)
# Requirement already satisfied: pyproj>=2.2.0 in /opt/conda/lib/python3.7/site-packages (from geopandas>=0.5.0->keplergl) (3.2.1)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.5.0->keplergl) (0.7.2)
# Requirement already satisfied: six>=1.7 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.5.0->keplergl) (1.15.0)
# Requirement already satisfied: attrs>=17 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.5.0->keplergl) (21.2.0)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.5.0->keplergl) (1.1.1)
# Requirement already satisfied: munch in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.5.0->keplergl) (2.5.0)
# Requirement already satisfied: click>=4.0 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.5.0->keplergl) (8.0.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.5.0->keplergl) (58.0.4)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas>=0.5.0->keplergl) (2021.10.8)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from click>=4.0->fiona>=1.8->geopandas>=0.5.0->keplergl) (4.8.1)
# Requirement already satisfied: ipython>=4.0.0 in /opt/conda/lib/python3.7/site-packages (from ipywidgets<8,>=7.0.0->keplergl) (7.27.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/conda/lib/python3.7/site-packages (from ipywidgets<8,>=7.0.0->keplergl) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.7/site-packages (from ipywidgets<8,>=7.0.0->keplergl) (6.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.7/site-packages (from ipywidgets<8,>=7.0.0->keplergl) (5.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/conda/lib/python3.7/site-packages (from ipywidgets<8,>=7.0.0->keplergl) (5.1.3)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (1.4.1)
# Requirement already satisfied: jupyter-client<8.0 in /opt/conda/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (6.1.7)
# Requirement already satisfied: tornado<7.0,>=4.2 in /opt/conda/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (6.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /opt/conda/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (0.1.2)
# Requirement already satisfied: argcomplete>=1.12.3 in /opt/conda/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (1.12.3)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->click>=4.0->fiona>=1.8->geopandas>=0.5.0->keplergl) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->click>=4.0->fiona>=1.8->geopandas>=0.5.0->keplergl) (3.10.0.2)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.17.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (4.8.0)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (2.9.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (3.0.20)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (5.1.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/conda/lib/python3.7/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.7.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /opt/conda/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (4.7.1)
# Requirement already satisfied: pyzmq>=13 in /opt/conda/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/lib/python3.7/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (2.8.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.0.0->keplergl) (3.2.0)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.0.0->keplergl) (0.17.3)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.23.0->keplergl) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.23.0->keplergl) (1.19.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.7/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /opt/conda/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (6.1.6)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (20.1.0)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (5.6.1)
# Requirement already satisfied: Send2Trash in /opt/conda/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (1.8.0)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.9.4)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (3.0.1)
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (1.14.6)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (2.20)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (2.0.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.3)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (4.0.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.5.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.8.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (21.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (2.4.7)

# %%
! pip install h3
# Out:
# Requirement already satisfied: h3 in /opt/conda/lib/python3.7/site-packages (3.7.3)

# %%
! pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /opt/conda/lib/python3.7/site-packages (0.10.2)
# Requirement already satisfied: pandas>=0.25.0 in /opt/conda/lib/python3.7/site-packages (from geopandas) (1.2.3)
# Requirement already satisfied: fiona>=1.8 in /opt/conda/lib/python3.7/site-packages (from geopandas) (1.8.21)
# Requirement already satisfied: shapely>=1.6 in /opt/conda/lib/python3.7/site-packages (from geopandas) (1.8.0)
# Requirement already satisfied: pyproj>=2.2.0 in /opt/conda/lib/python3.7/site-packages (from geopandas) (3.2.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: six>=1.7 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: attrs>=17 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: munch in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (58.0.4)
# Requirement already satisfied: click>=4.0 in /opt/conda/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (8.0.1)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from click>=4.0->fiona>=1.8->geopandas) (4.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.25.0->geopandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.25.0->geopandas) (1.19.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->click>=4.0->fiona>=1.8->geopandas) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->click>=4.0->fiona>=1.8->geopandas) (3.10.0.2)

# %%
! pip install pandasql
# Out:
# Requirement already satisfied: pandasql in /opt/conda/lib/python3.7/site-packages (0.7.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from pandasql) (1.19.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from pandasql) (1.2.3)
# Requirement already satisfied: sqlalchemy in /opt/conda/lib/python3.7/site-packages (from pandasql) (1.3.19)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas->pandasql) (2021.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)

# %%
import pandas as pd
import keplergl
from keplergl import KeplerGl
import h3
import requests
import geopandas as gpd
from pandasql import PandaSQL
pdsql = PandaSQL()

import arcgis
from arcgis.gis import GIS
from arcgis.mapping import WebMap, WebScene
from arcgis.features import FeatureLayer
from arcgis.features import GeoAccessor, GeoSeriesAccessor

# %%
# https://developers.arcgis.com/rest/services-reference/query-feature-service-layer-.htm
# This query will: return all records (where=1=1), all fields (outFields=*), the correct projection for H3 (outSR=4326), and geojson (f=geojson)

url = requests.get("https://services.arcgis.com/q3Zg9ERurv23iysr/ArcGIS/rest/services/tweets_for_testing_02082022/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=geojson")
df = gpd.GeoDataFrame().from_features(url.json())
df
# Out:
#                          geometry  OBJECTID                      created_at  \
# 0     POINT (-118.24992 34.05512)         1  Tue Dec 24 08:00:00 +0000 2019
# 1     POINT (-118.32064 34.10054)         2  Tue Dec 24 08:00:06 +0000 2019
# 2     POINT (-117.86996 33.59552)         3  Tue Dec 24 08:02:06 +0000 2019
# 3     POINT (-118.35001 34.11000)         4  Tue Dec 24 08:02:32 +0000 2019
# 4     POINT (-118.45592 34.16640)         5  Tue Dec 24 08:03:04 +0000 2019
# ...                           ...       ...                             ...
# 4582  POINT (-118.30684 34.09225)      4583  Wed Dec 25 04:58:32 +0000 2019
# 4583  POINT (-118.32886 34.11035)      4584  Wed Dec 25 04:58:38 +0000 2019
# 4584  POINT (-117.04260 32.95420)      4585  Wed Dec 25 04:58:44 +0000 2019
# 4585  POINT (-117.70836 33.81114)      4586  Wed Dec 25 04:59:09 +0000 2019
# 4586  POINT (-118.30101 34.08816)      4587  Wed Dec 25 04:59:39 +0000 2019
#
#      Polarity Emotion Cognition  \
# 0         neg     sad      nana
# 1         nut     hpy      real
# 2         neg     sad      fict
# 3         neg     nut      nana
# 4         pos     sad      nana
# ...       ...     ...       ...
# 4582      nut     nut      nana
# 4583      pos     nut      real
# 4584      nut     hpy      nana
# 4585      nut     hpy      real
# 4586      nut     nut      fict
#
#                                                    text  created_at_Converted  \
# 0     Wow! @cecewinans is a Masterclass! Anointed gr...         1577174400000
# 1     ?????? STAYCATION™? ?????? #CHROMECAM #FAMBAM™...         1577174406000
# 2     Pink ocean!  #pinkocean #pinksea #pink#pastelp...         1577174526000
# 3     My baby! I pet da pooch! #instagay #instadog #...         1577174552000
# 4       14816 Weddington Street https://t.co/Wqh8ajt860         1577174584000
# ...                                                 ...                   ...
# 4582  0458Z N223LA LAPD AIR SUPPORT DIVISION Squawk:...         1577249912000
# 4583  0458Z N962LA COUNTY OF LOS ANGELES Squawk: 120...         1577249918000
# 4584  So this happened after #movember #beard for th...         1577249924000
# 4585  At 20:51 the Fremont Canyon Weather Station re...         1577249949000
# 4586  0459Z N962LA COUNTY OF LOS ANGELES Squawk: 120...         1577249979000
#
#             lat         lon
# 0     34.055116 -118.249915
# 1     34.100539 -118.320639
# 2     33.595517 -117.869962
# 3     34.110001 -118.350005
# 4     34.166399 -118.455921
# ...         ...         ...
# 4582  34.092250 -118.306844
# 4583  34.110352 -118.328864
# 4584  32.954198 -117.042602
# 4585  33.811136 -117.708363
# 4586  34.088157 -118.301015
#
# [4587 rows x 10 columns]

# %%
def calculate_h3_7(lat, lng):
    h3_hex = h3.geo_to_h3(lat, lng, resolution_7)
    return h3_hex
resolution_7 = 7

def calculate_h3_8(lat, lng):
    h3_hex = h3.geo_to_h3(lat, lng, resolution_8)
    return h3_hex
resolution_8 = 8

# %%
df['h3_7'] = df.apply(lambda row: calculate_h3_7(row['lat'], row['lon']), axis=1)
df['h3_8'] = df.apply(lambda row: calculate_h3_8(row['lat'], row['lon']), axis=1)
df
# Out:
#                          geometry  OBJECTID                      created_at  \
# 0     POINT (-118.24992 34.05512)         1  Tue Dec 24 08:00:00 +0000 2019
# 1     POINT (-118.32064 34.10054)         2  Tue Dec 24 08:00:06 +0000 2019
# 2     POINT (-117.86996 33.59552)         3  Tue Dec 24 08:02:06 +0000 2019
# 3     POINT (-118.35001 34.11000)         4  Tue Dec 24 08:02:32 +0000 2019
# 4     POINT (-118.45592 34.16640)         5  Tue Dec 24 08:03:04 +0000 2019
# ...                           ...       ...                             ...
# 4582  POINT (-118.30684 34.09225)      4583  Wed Dec 25 04:58:32 +0000 2019
# 4583  POINT (-118.32886 34.11035)      4584  Wed Dec 25 04:58:38 +0000 2019
# 4584  POINT (-117.04260 32.95420)      4585  Wed Dec 25 04:58:44 +0000 2019
# 4585  POINT (-117.70836 33.81114)      4586  Wed Dec 25 04:59:09 +0000 2019
# 4586  POINT (-118.30101 34.08816)      4587  Wed Dec 25 04:59:39 +0000 2019
#
#      Polarity Emotion Cognition  \
# 0         neg     sad      nana
# 1         nut     hpy      real
# 2         neg     sad      fict
# 3         neg     nut      nana
# 4         pos     sad      nana
# ...       ...     ...       ...
# 4582      nut     nut      nana
# 4583      pos     nut      real
# 4584      nut     hpy      nana
# 4585      nut     hpy      real
# 4586      nut     nut      fict
#
#                                                    text  created_at_Converted  \
# 0     Wow! @cecewinans is a Masterclass! Anointed gr...         1577174400000
# 1     ?????? STAYCATION™? ?????? #CHROMECAM #FAMBAM™...         1577174406000
# 2     Pink ocean!  #pinkocean #pinksea #pink#pastelp...         1577174526000
# 3     My baby! I pet da pooch! #instagay #instadog #...         1577174552000
# 4       14816 Weddington Street https://t.co/Wqh8ajt860         1577174584000
# ...                                                 ...                   ...
# 4582  0458Z N223LA LAPD AIR SUPPORT DIVISION Squawk:...         1577249912000
# 4583  0458Z N962LA COUNTY OF LOS ANGELES Squawk: 120...         1577249918000
# 4584  So this happened after #movember #beard for th...         1577249924000
# 4585  At 20:51 the Fremont Canyon Weather Station re...         1577249949000
# 4586  0459Z N962LA COUNTY OF LOS ANGELES Squawk: 120...         1577249979000
#
#             lat         lon             h3_7             h3_8
# 0     34.055116 -118.249915  8729a1d75ffffff  8829a1d719fffff
# 1     34.100539 -118.320639  8729a1d6affffff  8829a1d6a1fffff
# 2     33.595517 -117.869962  8729a54f3ffffff  8829a54f3dfffff
# 3     34.110001 -118.350005  8729a1d6bffffff  8829a1d6bbfffff
# 4     34.166399 -118.455921  8729a1885ffffff  8829a18855fffff
# ...         ...         ...              ...              ...
# 4582  34.092250 -118.306844  8729a1d45ffffff  8829a1d6adfffff
# 4583  34.110352 -118.328864  8729a1d6bffffff  8829a1d6b5fffff
# 4584  32.954198 -117.042602  8729a409cffffff  8829a409c7fffff
# 4585  33.811136 -117.708363  8729a0a34ffffff  8829a0a343fffff
# 4586  34.088157 -118.301015  8729a1d45ffffff  8829a1d45bfffff
#
# [4587 rows x 12 columns]

# %%
df_for_sql = df[['OBJECTID','Polarity', 'Emotion','Cognition','created_at_Converted','h3_7']]
df_for_sql
# Out:
#       OBJECTID Polarity Emotion Cognition  created_at_Converted  \
# 0            1      neg     sad      nana         1577174400000
# 1            2      nut     hpy      real         1577174406000
# 2            3      neg     sad      fict         1577174526000
# 3            4      neg     nut      nana         1577174552000
# 4            5      pos     sad      nana         1577174584000
# ...        ...      ...     ...       ...                   ...
# 4582      4583      nut     nut      nana         1577249912000
# 4583      4584      pos     nut      real         1577249918000
# 4584      4585      nut     hpy      nana         1577249924000
# 4585      4586      nut     hpy      real         1577249949000
# 4586      4587      nut     nut      fict         1577249979000
#
#                  h3_7
# 0     8729a1d75ffffff
# 1     8729a1d6affffff
# 2     8729a54f3ffffff
# 3     8729a1d6bffffff
# 4     8729a1885ffffff
# ...               ...
# 4582  8729a1d45ffffff
# 4583  8729a1d6bffffff
# 4584  8729a409cffffff
# 4585  8729a0a34ffffff
# 4586  8729a1d45ffffff
#
# [4587 rows x 6 columns]

# %%
pd.set_option('max_columns', None)
# pd.set_option("max_rows", None)
df2 = pdsql("SELECT COUNT(OBJECTID), Polarity, Emotion, Cognition, h3_7 FROM df_for_sql WHERE Polarity='neg' AND Emotion='sad' GROUP BY h3_7;")
df2
# Out:
#      COUNT(OBJECTID) Polarity Emotion Cognition             h3_7
# 0                  1      neg     sad      fict  8729a0022ffffff
# 1                  1      neg     sad      nana  8729a0031ffffff
# 2                  1      neg     sad      fict  8729a0070ffffff
# 3                  1      neg     sad      nana  8729a0106ffffff
# 4                  1      neg     sad      nana  8729a0134ffffff
# ..               ...      ...     ...       ...              ...
# 238                2      neg     sad      fict  8729a638affffff
# 239                1      neg     sad      fict  8729a684effffff
# 240                1      neg     sad      fict  8729a6ad4ffffff
# 241                1      neg     sad      fict  8729a6b80ffffff
# 242                1      neg     sad      real  8729a6b86ffffff
#
# [243 rows x 5 columns]

# %%
url1 = requests.get("https://services.arcgis.com/q3Zg9ERurv23iysr/ArcGIS/rest/services/h3_7_for_testing_02092022/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=geojson")
sdf = gpd.GeoDataFrame().from_features(url1.json())
sdf
# Out:
#                                                geometry  OBJECTID  \
# 0     POLYGON ((-118.67772 34.27169, -118.69388 34.2...         1
# 1     POLYGON ((-117.72721 34.13002, -117.74343 34.1...         2
# 2     POLYGON ((-117.48131 33.92797, -117.49752 33.9...         3
# 3     POLYGON ((-116.52738 32.81741, -116.54350 32.8...         4
# 4     POLYGON ((-118.01784 34.05138, -118.03403 34.0...         5
# ...                                                 ...       ...
# 2794  POLYGON ((-117.16039 33.41213, -117.17655 33.4...      2795
# 2795  POLYGON ((-118.11054 33.79289, -118.12669 33.7...      2796
# 2796  POLYGON ((-116.96282 32.90251, -116.97892 32.9...      2797
# 2797  POLYGON ((-117.37905 33.46499, -117.39520 33.4...      2798
# 2798  POLYGON ((-117.05977 32.94718, -117.07587 32.9...      2799
#
#                  h3_7  uhi_annual_day  uhi_annual_night  uhi_summer_day  \
# 0     8729a18cdffffff        0.345653          0.227397        0.301488
# 1     8729a0375ffffff       -0.268084         -0.419603        0.314226
# 2     8729a0149ffffff        0.758607          0.782472       -0.168685
# 3     8729a4586ffffff       -0.015748         -0.017824        0.154635
# 4     8729a1d13ffffff        3.945150          0.080957        4.295367
# ...               ...             ...               ...             ...
# 2794  8729a09b6ffffff       -0.032936         -0.197118        0.283647
# 2795  8729a56a0ffffff        1.445860          0.418967        0.447820
# 2796  8729a4096ffffff        2.652881         -0.060006        3.760198
# 2797  8729a091bffffff        0.407579         -0.313903        1.017257
# 2798  8729a409dffffff        0.658666          0.294407        0.551346
#
#       uhi_summer_night  uhi_winter_day  uhi_winter_night     ozone     pm_2_5  \
# 0             0.478674        0.450898          0.043094  0.021300   3.694587
# 1             0.178933       -0.678405         -1.004927  0.049939   9.330311
# 2             0.132064        1.191665          1.335518  0.062000  13.444260
# 3             0.025178       -0.137143         -0.053766  0.002948   0.720770
# 4             1.422607        3.115629         -1.219202  0.042121   9.841237
#        Shape__Area  Shape__Length
# 0     8.419223e+06   10802.460017
# 1     8.457481e+06   10826.696238
# 2     8.445513e+06   10818.923844
# 3     8.354925e+06   10760.322937
# 4     8.430825e+06   10809.665763
# ...            ...            ...
# 2794  8.397509e+06   10787.940597
# 2795  8.392641e+06   10785.107588
# 2796  8.343622e+06   10753.127318
# 2797  8.392448e+06   10784.743360
# 2798  8.344192e+06   10753.520183
#
# [2799 rows x 31 columns]

# %%
sdf2 = pd.merge(df2, sdf, on='h3_7', how='inner')
sdf2
# Out:
#      COUNT(OBJECTID) Polarity Emotion Cognition             h3_7  \
# 0                  1      neg     sad      fict  8729a0022ffffff
# 1                  1      neg     sad      nana  8729a0031ffffff
# 2                  1      neg     sad      fict  8729a0070ffffff
# 3                  1      neg     sad      nana  8729a0106ffffff
# 4                  1      neg     sad      nana  8729a0134ffffff
# ..               ...      ...     ...       ...              ...
# 226                1      neg     sad      real  8729a6251ffffff
# 227                1      neg     sad      nana  8729a6255ffffff
# 228                1      neg     sad      fict  8729a625cffffff
# 229                1      neg     sad      fict  8729a62e4ffffff
# 230                2      neg     sad      fict  8729a638affffff
#
#                                               geometry  OBJECTID  \
# 0    POLYGON ((-117.23779 33.91116, -117.25401 33.9...       626
# 1    POLYGON ((-117.21355 33.92341, -117.22978 33.9...      1461
# 2    POLYGON ((-117.36031 33.98937, -117.37653 33.9...       501
# 3    POLYGON ((-117.21227 33.78379, -117.22848 33.7...      2371
# 4    POLYGON ((-117.18743 33.72619, -117.20363 33.7...      2346
# ..                                                 ...       ...
# 226  POLYGON ((-116.50613 33.83443, -116.52239 33.8...      1979
# 227  POLYGON ((-116.50606 33.81112, -116.52232 33.8...       841
# 228  POLYGON ((-116.53056 33.84561, -116.54683 33.8...      1076
# 229  POLYGON ((-116.40847 33.81297, -116.42473 33.8...      1309
# 230  POLYGON ((-116.23753 33.71106, -116.25379 33.7...      2124
#
#      uhi_annual_day  uhi_annual_night  uhi_summer_day  uhi_summer_night  \
# 0          1.676413         -0.011744        1.534423          0.824915
# 1          1.465650          0.273976        1.483496          1.033829
# 2          0.421552          0.708815       -0.231745          0.958031
# 3          0.099021         -0.135503        0.164432         -0.078215
# 4          1.943551         -0.674175        3.070389          0.006172
# ..              ...               ...             ...               ...
# 226       -0.190656          0.382645       -0.295095          0.058871
# 227       -0.518508          0.418347       -0.478485         -0.009975
# 228       -0.427998          0.734530       -0.424240          0.318661
# 229       -0.236537          0.000210       -0.244660         -0.238559
# 230        0.430913          1.084872        0.092351          0.821917
#
#      uhi_winter_day  uhi_winter_night     ozone     pm_2_5  diesel_pm  \
# 0          1.922171         -0.881475  0.065000  12.890000  21.353466
# 1          1.629289         -0.446311  0.065000  12.890000  12.623909
# 2          1.226376          0.431426  0.065000  12.894069  32.799361
# 3          0.037086         -0.169034  0.003495   0.647863   0.229037
# 4          0.781364         -1.055616  0.062000  11.519058   7.498635
# ..              ...               ...       ...        ...        ...
# 226       -0.087752          0.673835  0.068000   7.017428   9.464455
# 227       -0.484783          0.801612  0.068000   7.020000   8.856952
sdf2.dtypes
# Out:
# COUNT(OBJECTID)              int64
# Polarity                    object
# Emotion                     object
# Cognition                   object
# h3_7                        object
# geometry                  geometry
# OBJECTID                     int64
# uhi_annual_day             float64
# uhi_annual_night           float64
# uhi_summer_day             float64
# uhi_summer_night           float64
# uhi_winter_day             float64
# uhi_winter_night           float64
# ozone                      float64
# pm_2_5                     float64
# diesel_pm                  float64
# drinking_water             float64
# pesticide_use              float64
# toxic_releases             float64
# traffic                    float64
# cleanup_sites              float64
# groundwater_threats        float64
# hazardous_waste            float64
# impaired_water_body        float64
# solid_waste_sites          float64
# asthma                     float64
# cardiovascular_disease     float64
# low_birth_weight           float64
# educational_attainment     float64
# housing_burden             float64
# linguistic_isolation       float64
# poverty                    float64
# unemployment               float64
# Shape__Area                float64
# Shape__Length              float64
# dtype: object

# %%
# For Kepler, you need to change the geometry type above to object - this code will do that...
sdf3 = sdf2.astype({'geometry':str})

# %%
sdf3.dtypes
# Out:
# COUNT(OBJECTID)             int64
# Polarity                   object
# Emotion                    object
# Cognition                  object
# h3_7                       object
# geometry                   object
# OBJECTID                    int64
# uhi_annual_day            float64
# uhi_annual_night          float64
# uhi_summer_day            float64
# uhi_summer_night          float64
# uhi_winter_day            float64
# uhi_winter_night          float64
# ozone                     float64
# pm_2_5                    float64
# diesel_pm                 float64
# drinking_water            float64
# pesticide_use             float64
# toxic_releases            float64
# traffic                   float64
# cleanup_sites             float64
# groundwater_threats       float64
# hazardous_waste           float64
# impaired_water_body       float64
# solid_waste_sites         float64
# asthma                    float64
# cardiovascular_disease    float64
# low_birth_weight          float64
# educational_attainment    float64
# housing_burden            float64
# linguistic_isolation      float64
# poverty                   float64
# unemployment              float64
# Shape__Area               float64
# Shape__Length             float64
# dtype: object

# %%
sdf4 = GeoAccessor.from_geodataframe(sdf2, False, column_name='geometry')
# Out:
# Error acquiring spatial reference from GeoDataFrame Spatial reference will not be set.'DataFrame' object has no attribute 'crs'

# %%
m1 = GIS().map("Los Angeles")
m1.zoom = 7
m1.center = [33.5,-117.5]
sdf4.spatial.plot(map_widget = m1,
                  renderer_type = 'c',  # for class breaks renderer
                  method = 'esriClassifyNaturalBreaks',
                  class_count = 5,  # choose the number of classes
                  col = 'COUNT(OBJECTID)',  # numeric column to classify
                  cmap = 'Reds',
                  alpha=0.7  # specify opacity
       )

m1.legend = True
m1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-1e4723fe-40b7-406a-8c51-3edee45f989f"><img src=""></img></div>
# <div class="map-html-embed-preview-1e4723fe-40b7-406a-8c51-3edee45f989f"></div>

# %%
config = {
'version': 'v1',
'config': {
    'mapState': {
        'latitude': 33.5,
        'longitude': -117.5,
        'zoom': 7}
    }
}

# %%
map1 = KeplerGl(height=400, data={'data_1': sdf3}, config=config)
map1
# Out:
# KeplerGl(config={'version': 'v1', 'config': {'mapState': {'latitude': 33.5, 'longitude': -117.5, 'zoom': 7}}},…
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
map1.save_to_html(file_name='/arcgis/home/Test_Data/Test_Map_02092022_v1.html')
# Out:
# Map saved to /arcgis/home/Test_Data/Test_Map_02092022_v1.html!
